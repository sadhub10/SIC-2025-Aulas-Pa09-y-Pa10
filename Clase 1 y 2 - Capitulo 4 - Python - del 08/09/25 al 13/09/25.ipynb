# %% [markdown]
# <a href="https://colab.research.google.com/github/sadhub10/Colabs-de-Clases/blob/main/Clase%201%20y%202%20-%20Capitulo%204%20-%20Python%20-%20del%2008/09/25%20al%2013/09/25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Estructuras de Datos**

# %% [markdown]
# # PILA

# %% [markdown]
# La analogía más común y fácil de entender para una pila (stack) es una:
# ## Pila de platos. 🍽️
#
# Imagina que estás en una cocina y apilas los platos limpios uno encima del otro.
#
# Cuando pones un plato nuevo, lo colocas en la parte superior de la pila.
#
# Cuando necesitas un plato, lo tomas del tope de la pila.
#
# Esto ilustra perfectamente el principio LIFO (Last-In, First-Out): el último plato que se puso es el primero que se saca. No puedes acceder fácilmente a los platos de abajo sin quitar primero los que están encima.

# %%
stack = []

stack.append(1)
stack.append(2)
stack.append(3)

print(stack)
# Out:
# [1, 2, 3]

# %% [markdown]
# ## Métodos Principales:
# 1. push()
# Este método se usa para agregar un nuevo elemento a la parte superior de la pila. Es la operación de "apilar" un nuevo ítem.
#
# Analogía: Poner un nuevo libro encima de una pila de libros.
#
# 2. pop()
# Este método elimina y devuelve el elemento que está en la cima de la pila. Es el método que respeta la regla LIFO.
#
# Analogía: Tomar el libro que está hasta arriba de la pila para leerlo.
#
# 3. peek() (o top())
# Este método devuelve el elemento en la cima de la pila sin eliminarlo. Es útil para "echar un vistazo" al siguiente elemento sin modificar la pila.
#
# Analogía: Mirar la portada del libro que está en la parte superior sin levantarlo de la pila.

# %% [markdown]
# ## Método push()

# %%
# Create a list to act as a stack
my_stack = []

# Conceptual 'push' operation
my_stack.append("item_A")
my_stack.append("item_B")
my_stack.append("item_C")

print(my_stack) # Output: ['item_A']
# Out:
# ['item_A', 'item_B', 'item_C']

# %%
# Creamos una pila vacía
pila = []

print("Estado inicial de la pila:", pila)

# Operación PUSH: Añadimos elementos a la pila
pila.append("Plato 1")
print("Después de push 'Plato 1':", pila)

pila.append("Plato 2")
print("Después de push 'Plato 2':", pila)

pila.append("Plato 3")
print("Después de push 'Plato 3':", pila)
# Out:
# Estado inicial de la pila: []
# Después de push 'Plato 1': ['Plato 1']
# Después de push 'Plato 2': ['Plato 1', 'Plato 2']
# Después de push 'Plato 3': ['Plato 1', 'Plato 2', 'Plato 3']

# %%
pila_coches = []

print("Estado inicial de la pila:", pila_coches)

#Operaciones PUSH:
pila_coches.append("Ferrari")
print("Después de push 'Coche 1':", pila_coches)

pila_coches.append("Ford")
print("Después de push 'Coche 2':", pila_coches)

pila_coches.append("Mclaren")
print("Después de push 'Coche 3':", pila_coches)

pila_coches.append("Toyota")
print("Después de push 'Coche 4':", pila_coches)
# Out:
# Estado inicial de la pila: []
# Después de push 'Coche 1': ['Ferrari']
# Después de push 'Coche 2': ['Ferrari', 'Ford']
# Después de push 'Coche 3': ['Ferrari', 'Ford', 'Mclaren']
# Después de push 'Coche 4': ['Ferrari', 'Ford', 'Mclaren', 'Toyota']

# %%
pila_coches = []

print("Estado inicial de la pila:", pila_coches)

# Usando extend() para añadir múltiples elementos
pila_coches.extend(["Ferrari", "Ford", "Mclaren", "Toyota"])
print(pila_coches)
# Out:
# Estado inicial de la pila: []
# ['Ferrari', 'Ford', 'Mclaren', 'Toyota']

# %% [markdown]
# ## Método pop()

# %%
# Partimos de una pila ya con elementos
pila = ["Plato 1", "Plato 2", "Plato 3"]

print("Pila antes de pop:", pila)

# Operación POP: Eliminamos el último elemento
ultimo_plato = pila.pop()
print("Elemento 'pop':", ultimo_plato)
print("Pila después de pop:", pila)

# Hacemos otro pop
segundo_plato = pila.pop()
print("Elemento 'pop':", segundo_plato)
print("Pila después de otro pop:", pila)
# Out:
# Pila antes de pop: ['Plato 1', 'Plato 2', 'Plato 3']
# Elemento 'pop': Plato 3
# Pila después de pop: ['Plato 1', 'Plato 2']
# Elemento 'pop': Plato 2
# Pila después de otro pop: ['Plato 1']

# %%
# Partimos de una pila ya con elementos
pila = ["Plato 1", "Plato 2", "Plato 3"]

print("Pila antes de pop:", pila)

# Operación POP: Eliminamos el último elemento
ultimo_plato = pila.pop()
print("Elemento 'pop':", ultimo_plato)
print("Pila después de pop:", pila)
# Out:
# Pila antes de pop: ['Plato 1', 'Plato 2', 'Plato 3']
# Elemento 'pop': Plato 2
# Pila después de pop: ['Plato 1', 'Plato 3']

# %%
pila_coches = ["Coche 1", "Coche 2"]

print("Pila antes de pop:", pila_coches)

# Operación POP: Eliminamos el último elemento

ultimo_coche = pila_coches.pop()
print("Elemento 'pop':", ultimo_coche)
print("Pila después de pop:", pila_coches)
# Out:
# Pila antes de pop: ['Coche 1', 'Coche 2']
# Elemento 'pop': Coche 2
# Pila después de pop: ['Coche 1']

# %%
pila_paises = ["España", "Francia", "Alemania"]

print("Pila antes de pop:", pila_paises)

# Operación POP: Eliminamos el último elemento

ultimo_pais = pila_paises.pop()
print("Elemento 'pop':", ultimo_pais)
print("Pila después de pop:", pila_paises)
penultimo_pais = pila_paises.pop()
print("Elemento 'pop':", ultimo_pais)
print("Pila después de pop:", pila_paises)
# Out:
# Pila antes de pop: ['España', 'Francia', 'Alemania']
# Elemento 'pop': Alemania
# Pila después de pop: ['España', 'Francia']
# Elemento 'pop': Alemania
# Pila después de pop: ['España']

# %% [markdown]
# ## Método peek()

# %%
# Partimos de una pila con elementos
pila = ["Plato 1"]

# Verificamos que la pila no esté vacía
if len(pila) > 0:
    # Operación PEEK: Miramos el elemento superior sin sacarlo
    elemento_superior = pila[-1]
    print("Elemento en la cima (peek):", elemento_superior)
    print("La pila no ha cambiado:", pila)
else:
    print("La pila está vacía.")
# Out:
# Elemento en la cima (peek): Plato 1
# La pila no ha cambiado: ['Plato 1']

# %%
#Pila de Coches
pila_coches = ["Coche 1", "Coche 2"]
#Acceder a la longitud de la lista
len(pila_coches)
#Observar el ultimo elemnto de nuestra pila
ultimo_coche = pila_coches[-1]
print(ultimo_coche)
#Pila sin modificaciones
print(pila_coches)
# Out:
# Coche 2
# ['Coche 1', 'Coche 2']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## COLA

# %% [markdown]
# Una cola funciona de manera opuesta a una pila. Mientras que en una pila solo se puede acceder al último elemento, en una cola el acceso se realiza por ambos extremos: uno para agregar elementos y otro para eliminarlos.

# %%
# Creamos una cola vacía usando una lista
cola_sencilla = []

# Agregamos elementos a la cola (operación 'enqueue')
cola_sencilla.append("elemento_1") #1ero
cola_sencilla.append("elemento_2") #2do
cola_sencilla.append("elemento_3") #3ro

print("Cola después de agregar elementos:", cola_sencilla)

# Eliminamos el primer elemento de la cola (operación 'dequeue')
primer_elemento = cola_sencilla.pop()

print("\nElemento eliminado:", primer_elemento)
print("Cola después de eliminar:", cola_sencilla)
# Out:
# Cola después de agregar elementos: ['elemento_1', 'elemento_2', 'elemento_3']
#
# Elemento eliminado: elemento_3
# Cola después de eliminar: ['elemento_1', 'elemento_2']

# %% [markdown]
# ## Operaciones Principales

# %% [markdown]
# #### Encolar (Enqueue):
# La operación de agregar un elemento al final de la cola.
#
#
# #### Desencolar (Dequeue):
# La operación de eliminar el elemento que está al principio de la cola.

# %%
from collections import deque

# 1. Crear una cola
cola = deque()

print("La cola está vacía:", len(cola) == 0)

# 2. Encolar (enqueue): agregar elementos al final
print("\n--- Agregando elementos a la cola (enqueue) ---")
cola.append("Tarea A")
cola.append("Tarea B")
cola.append("Tarea C")
print("Cola actual:", cola)

# 3. Desencolar (dequeue): eliminar el elemento del frente
print("\n--- Eliminando elementos de la cola (dequeue) ---")
tarea_atendida = cola.popleft()  # popleft() elimina el primer elemento
print("Elemento atendido:", tarea_atendida)
print("Cola después del primer dequeue:", cola)

tarea_atendida = cola.popleft()
print("Elemento atendido:", tarea_atendida)
print("Cola después del segundo dequeue:", cola)

# 4. Estado de la cola
print("\n--- Estado final ---")
print("La cola está vacía:", len(cola) == 0)
# Out:
# La cola está vacía: True
#
# --- Agregando elementos a la cola (enqueue) ---
# Cola actual: deque(['Tarea A', 'Tarea B', 'Tarea C'])
#
# --- Eliminando elementos de la cola (dequeue) ---
# Elemento atendido: Tarea A
# Cola después del primer dequeue: deque(['Tarea B', 'Tarea C'])
# Elemento atendido: Tarea B
# Cola después del segundo dequeue: deque(['Tarea C'])
#
# --- Estado final ---
# La cola está vacía: False

# %%
from collections import deque

# Creamos una instancia de deque
cola_profesional = deque()

# Encolar: agregamos elementos a la derecha
cola_profesional.append("cliente_A")
cola_profesional.append("cliente_B")
cola_profesional.append("cliente_C")
print(f"Cola de clientes: {cola_profesional}")

# Desencolar: quitamos el elemento de la izquierda
cliente_atendido = cola_profesional.popleft()
print(f"Cliente atendido: {cliente_atendido}")
print(f"Cola actual: {cola_profesional}")
# Out:
# Cola de clientes: deque(['cliente_A', 'cliente_B', 'cliente_C'])
# Cliente atendido: cliente_A
# Cola actual: deque(['cliente_B', 'cliente_C'])

# %%
# Cola (FIFO)
from collections import deque
cola = deque()
cola.append(10) # Agregamos el 10
cola.append(20) # Agregamos el 20
print(cola) # Salida: deque([10, 20])
print(cola.popleft()) # Salida: 10
print(cola) # Salida: deque([20])
# Out:
# deque([10, 20])
# 10
# deque([20])

# %% [markdown]
# otro ejemplo

# %%
from collections import deque
#Cola de paises
cola_paises = deque()
#Agregar Elementos
cola_paises.append("Colombia")
cola_paises.append("Oman")
cola_paises.append("Mexico")
#Eliminar elementos
print(cola_paises.popleft())
print(cola_paises)
# Out:
# Colombia
# deque(['Oman', 'Mexico'])

# %%
from collections import deque
cola_paises = deque(["España","Francia","Alemania"])
cola_paises.append("Italia")
print(cola_paises.popleft())
print(cola_paises)
# Out:
# España
# deque(['Francia', 'Alemania', 'Italia'])

# %% [markdown]
# ## ARBOLES BINARIOS

# %% [markdown]
# Un árbol binario es una estructura de datos jerárquica que se asemeja a un árbol genealógico. Cada nudo en el árbol tiene un valor y puede tener, como máximo, dos "hijos": un hijo izquierdo y un hijo derecho.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A diferencia de las estructuras de datos lineales como las listas,las pilas y las colas,los árboles organizan los datos de forma jerárquica.Esto los hace muy eficientes para buscar,Insertar y eliminar elementos.La base de un árbol es suraíz,el primer nodo del cual se desprenden todos los demás.Los nudos que no tienen hijos se llamanhojas.

# %% [markdown]
# ```
# # En Python,no existe un tipo de dato "árbol binario" incorporado. Por lo tanto, se suele definir con una clase:
#
# class Nodo
#
# que contiene tres atributos:
#
# valor:El dato que almacena el nodo.
#
# izquierda:Una referencia al nodo hijo izquierdo.
#
# derecha:Una referencia al nodo hijo derecho.
# ```

# %%
class Nodo:
    def __init__(self, valor):
        self.valor = valor
        self.izquierda = None  # Hijo izquierdo
        self.derecha = None    # Hijo derecho

# %% [markdown]
# ### **Recorridos**
# Estos son los métodos más importantes y se basan en un enfoque de recursión.
#
# * Inorden(Izquierda, Raíz, Derecha): Visita el subárbol izquierdo, luego la raíz y finalmente el subárbol derecho. Es útil para obtener los elementos de un árbol de búsqueda binaria en orden ascendente.
#
# * Preorden(Raíz, Izquierda, Derecha): Visita primero la raíz, luego el subárbol izquierdo y finalmente el subárbol derecho. Es útil para copiar un árbol.
#
# * Postorden(Izquierda, Derecha, Raíz): Visita el subárbol izquierdo, luego el subárbol derecho y finalmente la raíz. Es útil para eliminar el árbol por completo.

# %%
class Nodo:
    def __init__(self, valor):
        self.valor = valor
        self.izquierda = None
        self.derecha = None

# Creamos un árbol binario
raiz = Nodo(1)
raiz.izquierda = Nodo(2)
raiz.derecha = Nodo(3)
raiz.izquierda.izquierda = Nodo(4)

# Función para recorrer el árbol Inorden
def recorrido_inorden(nodo):
    if nodo:
        # 1. Recorre el subárbol izquierdo
        recorrido_inorden(nodo.izquierda)
        # 2. Visita la raíz
        print(nodo.valor, end=" ")
        # 3. Recorre el subárbol derecho
        recorrido_inorden(nodo.derecha)

print("Recorrido Inorden del árbol:")
recorrido_inorden(raiz.derecha)
# Out:
# Recorrido Inorden del árbol:
# 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Nodo:
    def __init__(self, valor):
        self.valor = valor
        self.izquierda = None
        self.derecha = None

# Creamos un árbol binario simple
# El árbol tiene la siguiente estructura:
#
#       A
#      / \
#     B   C
#    / \
#   D   E
#
raiz = Nodo('A')
raiz.izquierda = Nodo('B')
raiz.derecha = Nodo('C')
raiz.izquierda.izquierda = Nodo('D')
raiz.izquierda.derecha = Nodo('E')

# Función para recorrer el árbol en preorden
def recorrido_preorden(nodo):
    if nodo:
        # 1. Visita la raíz
        print(nodo.valor, end=" ")
        # 2. Recorre el subárbol izquierdo
        recorrido_preorden(nodo.izquierda)
        # 3. Recorre el subárbol derecho
        recorrido_preorden(nodo.derecha)

# Llamamos a la función para empezar el recorrido desde la raíz
print("Recorrido Preorden del árbol:")
recorrido_preorden(raiz.izquierda)
# Out:
# Recorrido Preorden del árbol:
# B D E

# %% [markdown]
# # BUSQUEDA SECUENCIAL

# %% [markdown]
# EN RESUMEN:  La búsqueda secuencial, también conocida como búsqueda lineal, es el algoritmo de búsqueda más simple y directo. Consiste en recorrer una lista o arreglo, elemento por elemento, desde el principio hasta el final, comparando cada uno con el valor que se busca.

# %% [markdown]
# #### Analogía 🔎
# Imagina que estás buscando un libro en un estante desordenado de una biblioteca. La única forma de encontrarlo es revisar cada libro, uno por uno, desde el primer libro del estante hasta el último.

# %% [markdown]
# #### Complejidad de Tiempo ⏱️
# La búsqueda secuencial tiene una complejidad de tiempo de O(n) (lineal). Esto significa que, en el peor de los casos, el número de operaciones es directamente proporcional al número de elementos (n) en la lista. Si la lista tiene 100 elementos, en el peor de los casos (si el elemento está al final o no existe), el algoritmo tendrá que hacer 100 comparaciones.

# %% [markdown]
# ### Qué podemos hacer?
# En Python, no se necesita una función especial para una búsqueda secuencial. Se puede realizar mediante un código de Python simple y básico:

# %% [markdown]
# ## 1. Uso de un for (bucle)

# %% [markdown]
# La forma más común de implementar una búsqueda secuencial es mediante un forbucle. Esto permite iterar por cada índice y valor de la lista.

# %%
def busqueda_secuencial_bucle(mi_lista, objetivo):
    """
    Busca un objetivo en una lista.
    Devuelve el índice si se encuentra o -1 si no se encuentra.
    """
    # Recorre la lista desde el primer elemento hasta el último
    for i in range(len(mi_lista)):
        # Si el elemento actual es igual al objetivo
        if mi_lista[i] == objetivo:
            return i  # Devuelve el índice si se encuentra

    # Si el bucle termina sin encontrar el objetivo
    return -1  # Devuelve -1 si no se encontró

mi_lista = [5, 2, 8, 10, 9]

# Llama a la función y muestra el resultado
print(f"El índice es: {busqueda_secuencial_bucle(mi_lista, 20)}")
# Out:
# El índice es: -1

# %% [markdown]
# ## 2. Uso del in (operador)

# %% [markdown]
# Para un enfoque mucho más sencillo, el operador de Python inrealiza una búsqueda secuencial en segundo plano. Comprueba la existencia de un elemento en una lista sin necesidad de escribir un bucle.

# %%
mi_lista = [5, 2, 8, 1, 9]

if 10 in mi_lista:
    print("está en la lista.")
else:
    print(" no está en la lista.")
# Out:
#  no está en la lista.

# %% [markdown]
# ## 3. Utilizando el .index() método

# %% [markdown]
# Si necesita el índice de un elemento encontrado, puede usar el método integrado .index() en una lista. Tenga cuidado con este método, ya que generará un error si no se encuentra el elemento.

# %%
mi_lista = [5, 5, 8, 1, 90]

try:
    indice = mi_lista.index(5)
    print(f"El índice es: {indice}")
except ValueError:
    print("Elemento no encontrado.")
# Out:
# El índice es: 0

# %%
mi_lista = [5, 2, 8, 1, 9]
indice = mi_lista.index(90)
print(f"El índice  es: {indice}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2023551374.py in <cell line: 0>()
#       1 mi_lista = [5, 2, 8, 1, 9]
# ----> 2 indice = mi_lista.index(90)
#       3 print(f"El índice  es: {indice}")
#
# ValueError: 90 is not in list

# %% [markdown]
# Ejemplo 1: Búsqueda Básica en una Lista de Números 🔢

# %%
def busqueda_secuencial_numeros(lista, objetivo):
    """Busca un número en una lista. Devuelve el índice o -1 si no está."""
    # Recorremos la lista desde el primer elemento hasta el último
    for i in range(len(lista)):
        # Comparamos el elemento actual con el objetivo
        if lista[i] == objetivo:
            return i  # Si coinciden, devolvemos el índice

    # Si el bucle termina y no se encontró el objetivo
    return -1

numeros = [10, 5, 20, 8, 15, 20, 30, 45, 43]

# Buscando un número que existe
indice_encontrado = busqueda_secuencial_numeros(numeros, 5)
print(f"El número se encuentra en el índice: {indice_encontrado}")

# Buscando un número que no existe
indice_no_encontrado = busqueda_secuencial_numeros(numeros, 80)
print(f"El número se encuentra en el índice: {indice_no_encontrado}")
# Out:
# El número se encuentra en el índice: 1
# El número se encuentra en el índice: -1

# %% [markdown]
# Ejemplo 2: Búsqueda en una Lista de Cadenas de Texto 📖

# %%
def busqueda_secuencial_palabras(lista_palabras, objetivo):
    """Busca una palabra en una lista. Devuelve el índice o -1."""
    # Recorremos la lista de palabras
    for i in range(len(lista_palabras)):
        # Comparamos la palabra actual con el objetivo
        if lista_palabras[i] == objetivo:
            return i

    # Si no se encuentra la palabra
    return "no esta"

diccionario_simple = ["manzana", "Pitahaya", "uva", "kiwi", "naranja", "Guaba","Pitahaya"]

# Buscando una palabra que existe
indice_banana = busqueda_secuencial_palabras(diccionario_simple, "Pitahaya")
print(f"La palabra 'banana' se encuentra en el índice: {indice_banana}")

# Buscando una palabra que no existe
indice_mango = busqueda_secuencial_palabras(diccionario_simple, "mango")
print(f"La palabra 'mango' se encuentra en el índice: {indice_mango}")
# Out:
# La palabra 'banana' se encuentra en el índice: 1
# La palabra 'mango' se encuentra en el índice: no esta

# %% [markdown]
# # BUSQUEDA BINARIA

# %% [markdown]
# #### Analogía 📖
# La mejor analogía para la búsqueda binaria es buscar una palabra en un diccionario impreso. No empiezas por la primera página. En su lugar, abres el libro aproximadamente por la mitad, miras la primera palabra de esa página y decides si tu palabra está antes o después de esa sección. Luego, repites el proceso en la mitad restante, descartando la otra mitad.

# %% [markdown]
# #### Complejidad de Tiempo ⏱️
# La búsqueda binaria tiene una complejidad de tiempo de O(logn) (logarítmica), mientras que la búsqueda lineal tiene una complejidad de O(n) (lineal).
#
# Esto significa que a medida que el número de elementos (n) crece, el tiempo que tarda la búsqueda binaria aumenta mucho más lentamente. Por ejemplo, en una lista de un millón de elementos, la búsqueda binaria podría encontrar un elemento en tan solo 20 pasos, mientras que una búsqueda lineal podría requerir un millón de pasos.

# %% [markdown]
# Ejemplo 1: Búsqueda de un Número Básico 🔢

# %%
def busqueda_binaria(lista_ordenada, objetivo):
    """
    Busca un objetivo en una lista ordenada usando el algoritmo de búsqueda binaria.
    Devuelve el índice del objetivo o -1 si no se encuentra.
    """
    izquierda, derecha = 0, len(lista_ordenada) - 1

    while izquierda <= derecha:
        medio = (izquierda + derecha) // 2
        valor_medio = lista_ordenada[medio]

        if valor_medio == objetivo:
            return medio  # El objetivo se encontró
        elif valor_medio < objetivo:
            izquierda = medio + 1  # Busca en la mitad derecha
        else:
            derecha = medio - 1  # Busca en la mitad izquierda

    return -1  # El objetivo no se encontró

# Lista ordenada para el ejemplo
numeros_ordenados = [2, 5, 8, 12, 16, 23, 38, 56, 72, 91]

# Buscando un número que existe
indice_encontrado = busqueda_binaria(numeros_ordenados, 23)
print(f"El número 23 se encuentra en el índice: {indice_encontrado}")

# Buscando un número que no existe
indice_no_encontrado = busqueda_binaria(numeros_ordenados, 10)
print(f"El número 10 se encuentra en el índice: {indice_no_encontrado}")
# Out:
# El número 23 se encuentra en el índice: 5
# El número 10 se encuentra en el índice: -1

# %% [markdown]
# #### Algoritmo del codigo:
# * Buscando 23: El algoritmo comienza con un rango de 0 a 9. En la primera iteración, el medio es el índice 4 (valor 16). Como 16 es menor que 23, el rango se ajusta a 5 a 9. El proceso continúa reduciendo el rango hasta que encuentra el 23.
# * Buscando 10: El proceso es similar, pero el número 10 nunca se encuentra en la lista. El rango se reduce en cada paso hasta que izquierda se vuelve mayor que derecha, y el bucle termina. El código devuelve -1.

# %%
def busqueda_binaria_con_pasos(lista_ordenada, objetivo):
    """
    Busca un objetivo en una lista ordenada y cuenta los pasos.
    Devuelve una tupla: (índice, número_de_pasos).
    """
    izquierda, derecha = 0, len(lista_ordenada) - 1
    pasos = 0  # Inicializamos el contador

    while izquierda <= derecha:
        pasos += 1  # Incrementamos el contador en cada iteración
        medio = (izquierda + derecha) // 2
        valor_medio = lista_ordenada[medio]

        if valor_medio == objetivo:
            return (medio, pasos)  # Se encontró, devolvemos el índice y los pasos
        elif valor_medio < objetivo:
            izquierda = medio + 1  # Buscamos en la mitad derecha
        else:
            derecha = medio - 1  # Buscamos en la mitad izquierda

    return (-1, pasos)  # No se encontró, devolvemos -1 y el total de pasos

# Lista de frutas ordenada alfabéticamente
frutas_ordenadas = ["arándano", "banana", "kiwi", "limón", "mango", "naranja", "uva"]

# Buscando la fruta "kiwi" (que sí existe)
indice_encontrado, pasos_encontrado = busqueda_binaria_con_pasos(frutas_ordenadas, "kiwi")
print(f"La fruta 'kiwi' se encuentra en el índice: {indice_encontrado}. Pasos: {pasos_encontrado}")

# Buscando la fruta "pera" (que no existe)
indice_no_encontrado, pasos_no_encontrado = busqueda_binaria_con_pasos(frutas_ordenadas, "pera")
print(f"La fruta 'pera' no se encuentra (índice: {indice_no_encontrado}). Pasos: {pasos_no_encontrado}")
# Out:
# La fruta 'kiwi' se encuentra en el índice: 2. Pasos: 3
# La fruta 'pera' no se encuentra (índice: -1). Pasos: 3

# %% [markdown]
# #### Ejemplo Visual 🔎
# Imagina que buscas el número 23 en la lista [2, 5, 8, 12, 16, 23, 38, 56, 72, 91].
#
# * **Iteración 1:**
#
# izquierda = 0, derecha = 9.
#
# medio = (0 + 9) // 2 = 4.
#
# valor_medio = lista[4] = 16.
#
# Como 16 < 23, el objetivo está a la derecha. El código ejecuta izquierda = medio + 1, que es 4 + 1 = 5.
#
# * Iteración 2: **texto en negrita**
#
# Tu nuevo rango de búsqueda es de izquierda = 5 a derecha = 9.
#
# medio = (5 + 9) // 2 = 7.
#
# valor_medio = lista[7] = 56.
#
# Como 56 > 23, el objetivo está a la izquierda. El código ejecuta derecha = medio - 1, que es 7 - 1 = 6.
#
# * **Iteración 3:**
#
# Tu nuevo rango de búsqueda es de izquierda = 5 a derecha = 6.
#
# medio = (5 + 6) // 2 = 5.
#
# valor_medio = lista[5] = 23.
#
# Como 23 == 23, se encuentra el objetivo y el algoritmo termina.
#
# Este proceso de ajuste de los límites izquierda y derecha es lo que le da a la búsqueda binaria su eficiencia logarítmica.

# %% [markdown]
# Ejemplo 2: Búsqueda en un Diccionario de Palabras 📖

# %%
def busqueda_binaria_palabra(lista_palabras, palabra_objetivo):
    """
    Busca una palabra en una lista ordenada alfabéticamente.
    """
    izquierda, derecha = 0, len(lista_palabras) - 1

    while izquierda <= derecha:
        medio = (izquierda + derecha) // 2
        palabra_media = lista_palabras[medio]

        if palabra_media == palabra_objetivo:
            return medio
        elif palabra_media < palabra_objetivo:
            izquierda = medio + 1
        else:
            derecha = medio - 1

    return -1

# Lista de palabras ordenada alfabéticamente
diccionario = ["agua", "casa", "gato", "perro", "sol", "verde"]

# Buscando una palabra que existe
indice_gato = busqueda_binaria_palabra(diccionario, "gato")
print(f"La palabra 'gato' se encuentra en el índice: {indice_gato}")

# Buscando una palabra que no existe
indice_cielo = busqueda_binaria_palabra(diccionario, "cielo")
print(f"La palabra 'cielo' se encuentra en el índice: {indice_cielo}")
# Out:
# La palabra 'gato' se encuentra en el índice: 2
# La palabra 'cielo' se encuentra en el índice: -1

# %% [markdown]
# La búsqueda binaria es un algoritmo que se usa para encontrar la posición (el índice) de un elemento cuyo valor conoces, pero su ubicación no

# %% [markdown]
# #### Acceso por Índice vs. Búsqueda Binaria
# Tabla comparativa para entender la diferencia:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Diferencias Busqueda Secuencial y Busqueda Binaria**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # TABLA HASH

# %% [markdown]
# EN RESUMEN: una tabla hash es el tipo de dato integrado conocido como diccionario (dict), que almacena pares de clave-valor de forma eficiente. Utiliza una función hash para convertir las claves en índices numéricos, permitiendo operaciones rápidas de inserción, búsqueda y eliminación de elementos.

# %% [markdown]
# ### Cómo Funcionan ⚙️
# Una tabla hash funciona asociando una clave con un valor . Utiliza una función hash para convertir la clave en un índice numérico, que luego se usa para almacenar el valor en un arreglo (o array ).
#
# * Función Hash : Es el corazón de la tabla. Toma una clave (como una palabra o un número de identificación) y la transforma en un número entero que servirá como índice. Esta función debe ser rápida y generar índices distribuidos uniformemente para evitar colisiones.
#
# * Índice : El número generado por la función hash.
#
# * Arreglo (Array) : Es la estructura de datos subyacente donde se almacenan los valores. Cada índice del arreglo corresponde a una "ranura" donde se puede guardar un valor.

# %% [markdown]
# ### Analogía 🗄️
# Imagina una biblioteca. La forma tradicional de buscar un libro es recorrer estante por estante (búsqueda secuencial). La búsqueda binaria sería como buscar en un catálogo ordenado.
#
# Una tabla hash es como un sistema de almacenamiento automatizado. Cuando llega un libro, la biblioteca le asigna un código único (la función hash ) que te dice exactamente en qué compartimento (el índice ) guardarlo. Cuando quieras el libro, simplemente le das el código a la máquina, que te lo entregará al instante. No necesitas buscar en ningún otro lugar.

# %% [markdown]
# En Python, el tipo de dato dict(diccionario) es una implementación de una tabla hash. Su uso es intuitivo y te permite ver el poder de esta estructura.

# %%
# Un diccionario es una tabla hash en Python
contactos = {}

# 1. Inserción (Operación O(1))
# Asignamos valores a claves
contactos["Juan Perez"] = "123-456-7890"
contactos["Maria Lopez"] = "987-654-3210"
print("Contactos:", contactos)

# 2. Búsqueda (Operación O(1))
# Buscamos el número de teléfono de Juan
print("Teléfono de Juan:", contactos["Juan Perez"])

# 3. Eliminación (Operación O(1))
# Eliminamos a Maria de la lista
del contactos["Maria Lopez"]
print("Contactos después de eliminar:", contactos)
# Out:
# Contactos: {'Juan Perez': '123-456-7890', 'Maria Lopez': '987-654-3210'}
# Teléfono de Juan: 123-456-7890
# Contactos después de eliminar: {'Juan Perez': '123-456-7890'}

# %% [markdown]
# Ejemplo 1: Directorio Telefónico 📞

# %%
# Creamos un directorio telefónico como una tabla hash
directorio_telefonico = {
    "Ana": "987-654-3210",
    "Luis": "555-123-4567",
    "Sofía": "123-456-7890"
}

# 1. Búsqueda de un contacto
nombre = "Juan"
if nombre in directorio_telefonico:
    print(f"El teléfono de {nombre} es: {directorio_telefonico[nombre]}")
else:
    print(f"El contacto '{nombre}' no se encuentra.")

# 2. Agregar un nuevo contacto
directorio_telefonico["Carlos"] = "999-888-7777"
print("\nDirectorio actualizado:", directorio_telefonico)

# 3. Eliminar un contacto
del directorio_telefonico["Ana"]
print("Directorio después de eliminar a Ana:", directorio_telefonico)
# Out:
# El contacto 'Juan' no se encuentra.
#
# Directorio actualizado: {'Ana': '987-654-3210', 'Luis': '555-123-4567', 'Sofía': '123-456-7890', 'Carlos': '999-888-7777'}
# Directorio después de eliminar a Ana: {'Luis': '555-123-4567', 'Sofía': '123-456-7890', 'Carlos': '999-888-7777'}

# %% [markdown]
# Ejemplo 2: Mapeo de Códigos de Productos 📦

# %%
# Mapeo de códigos de productos a sus nombres
productos_ventas = {
    "P001": "Laptop",
    "P002": "Mouse inalámbrico",
    "P003": "Teclado mecánico"
}

# 2. Agregar un nuevo contacto
productos_ventas["P004"] = "cámara"
productos_ventas["P005"] = "teclado"

# Obtener la descripción de un producto
codigo_producto = "P005"
if codigo_producto in productos_ventas:
    print(f"El código {codigo_producto} corresponde a: {productos_ventas[codigo_producto]}")
else:
    print("Producto no encontrado.")
# Out:
# El código P005 corresponde a: teclado

# %% [markdown]
# ## `"El camino del programador está lleno de retos, pero cada desafío superado es una victoria que nadie les puede quitar. ¡Mantengan la curiosidad y la perseverancia, que el éxito es el resultado del esfuerzo!"`
